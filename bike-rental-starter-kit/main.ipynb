# %%
import pandas as pd
import os

# %% [markdown]
# # Load CSV Files

# %%
folder_path = "C:/Users/kamin/DataEngineerPortfolio/bike-rental-starter-kit/data"
file_list = os.listdir(folder_path)
file_list
# Out:
# ['JC-201601-citibike-tripdata.csv',
#  'JC-201602-citibike-tripdata.csv',
#  'JC-201603-citibike-tripdata.csv',
#  'JC-201604-citibike-tripdata.csv',
#  'JC-201605-citibike-tripdata.csv',
#  'JC-201606-citibike-tripdata.csv',
#  'JC-201607-citibike-tripdata.csv',
#  'JC-201608-citibike-tripdata.csv',
#  'JC-201609-citibike-tripdata.csv',
#  'JC-201610-citibike-tripdata.csv',
#  'JC-201611-citibike-tripdata.csv',
#  'JC-201612-citibike-tripdata.csv',
#  'newark_airport_2016.csv']

# %%
df_list = [pd.read_csv(os.path.join(folder_path,file)) for file in file_list if file.startswith('JC')]

df_list = pd.concat(df_list).reset_index(drop = True)

df_list['id'] = df_list.index

df_list
# Out:
#         Trip Duration           Start Time            Stop Time  \
# 0                 362  2016-01-01 00:02:52  2016-01-01 00:08:54
# 1                 200  2016-01-01 00:18:22  2016-01-01 00:21:42
# 2                 202  2016-01-01 00:18:25  2016-01-01 00:21:47
# 3                 248  2016-01-01 00:23:13  2016-01-01 00:27:21
# 4                 903  2016-01-01 01:03:20  2016-01-01 01:18:24
# ...               ...                  ...                  ...
# 247579            557  2016-12-31 23:10:16  2016-12-31 23:19:33
# 247580           2749  2016-12-31 23:29:39  2017-01-01 00:15:29
# 247581            173  2016-12-31 23:44:37  2016-12-31 23:47:31
# 247582           2424  2016-12-31 23:44:50  2017-01-01 00:25:14
# 247583           2419  2016-12-31 23:44:50  2017-01-01 00:25:10
#
#         Start Station ID Start Station Name  Start Station Latitude  \
# 0                   3186      Grove St PATH               40.719586
# ...

# %% [markdown]
# # Clean Data

# %% [markdown]
# ### Find Missing Values for Each Columns

# %%
missing_value = df_list.isnull().sum()
missing_value
# Out:
# Trip Duration                  0
# Start Time                     0
# Stop Time                      0
# Start Station ID               0
# Start Station Name             0
# Start Station Latitude         0
# Start Station Longitude        0
# End Station ID                 0
# End Station Name               0
# End Station Latitude           0
# End Station Longitude          0
# Bike ID                        0
# User Type                    380
# Birth Year                 18999
# Gender                         0
# id                             0
# dtype: int64

# %%
#find unique in User Type
df_list['User Type'].unique()
# Out:
# array(['Subscriber', 'Customer', nan], dtype=object)

# %% [markdown]
# ## Fixed DataType

# %%
df_list["Start Time"] = pd.to_datetime(df_list['Start Time'])
df_list['Stop Time'] = pd.to_datetime(df_list['Stop Time'])

df_list.dtypes
# Out:
# Trip Duration                       int64
# Start Time                 datetime64[ns]
# Stop Time                  datetime64[ns]
# Start Station ID                    int64
# Start Station Name                 object
# Start Station Latitude            float64
# Start Station Longitude           float64
# End Station ID                      int64
# End Station Name                   object
# End Station Latitude              float64
# End Station Longitude             float64
# Bike ID                             int64
# User Type                          object
# Birth Year                        float64
# Gender                              int64
# id                                  int64
# dtype: object

# %% [markdown]
# ## Add Colums

# %%
citibike_df['Age'] = datetime.now().year
citibike_df['Age'] = citibike_df['Age'] - citibike_df['Birth Year']
